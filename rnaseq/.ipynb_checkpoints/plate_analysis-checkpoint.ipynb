# %%
import os
import pandas as pd

# folder = "C:\\Users\\Van\\Desktop\\vancanwin\\pgap3cdg\\01.20.23\\"
folder = "C:\\Users\\vandu\\Desktop\\vancanwin\\pgap3cdg\\01.20.23\\"
filename_data = "plate-btg-412.csv"
filename_id = "plate-id.xlsx"
os.chdir(folder)

def normalize_plate384(filename):
    '''Enter file to read plate and normalize data'''
    df = pd.read_csv(filename)
    df_initial = df
    df_results_index = df[df.iloc[:,0].str.contains('Results', na=False)].index
    normalized_dataframe = pd.DataFrame([])
    for index in df_results_index:
        dateset_name = df.iloc[index,0]
        new_header = df.iloc[index+1,1:]
        df_results = df.iloc[index+2:index+18,1:] #row,col
        df_results = df_results.astype(int)
        df_results.columns = new_header
        df_avg_neg_controls = int(df_results.iloc[:,0:2].stack().median())
        df_min = df_results.stack().min()
        df_max = df_results.stack().max()
        df_range = df_max-df_min

        df_results_norm = (df_results - df_min)/df_range
        df.iloc[index+2:index+18,1:] = df_results_norm
    df.to_csv(folder+filename_data.split(".")[0]+"_normalized"+".csv")
    return(df)
    
normalize_plate384(folder+filename_data)
# Out:
#                                     Plate information  Unnamed: 1 Unnamed: 2  \
# 0                                                Plate     Repeat    Barcode
# 1                                                    1          1   H2060612
# 2                                                  NaN        NaN        NaN
# 3                               Background information        NaN        NaN
# 4                                                Plate      Label     Result
# ..                                                 ...        ...        ...
# 770  WARNING: Warning while loading plate. Stacker ...        NaN        NaN
# 771                                                NaN        NaN        NaN
# 772                                                NaN        NaN        NaN
# 773                                                NaN        NaN        NaN
# 774  Exported with EnVision Workstation version 1.1...        NaN        NaN
#
#           Unnamed: 3                    Unnamed: 4  \
# 0    Measured height  Chamber temperature at start
# 1                NaN                           NaN
# 2                NaN                           NaN
# 3                NaN                           NaN
# 4             Signal                  Flashes/Time
# ..               ...                           ...
# 770              NaN                           NaN
# 771              NaN                           NaN
# 772              NaN                           NaN
# 773              NaN                           NaN
# 774              NaN                           NaN
#
#                      Unnamed: 5         Unnamed: 6       Unnamed: 7  \
# 0    Chamber temperature at end  Humidity at start  Humidity at end
# 1                           NaN                NaN              NaN
# 2                           NaN                NaN              NaN
# 3                           NaN                NaN              NaN
# 4                      Meastime           MeasInfo              NaN
# ..                          ...                ...              ...
# 770                         NaN                NaN              NaN
# 771                         NaN                NaN              NaN
# 772                         NaN                NaN              NaN
# 773                         NaN                NaN              NaN
# 774                         NaN                NaN              NaN
#
#                        Unnamed: 8                  Unnamed: 9  ...  \
# 0    Ambient temperature at start  Ambient temperature at end  ...
# 1                             NaN                         NaN  ...
# 2                             NaN                         NaN  ...
# 3                             NaN                         NaN  ...
# 4                             NaN                         NaN  ...
# ..                            ...                         ...  ...
# 770                           NaN                         NaN  ...
# 771                           NaN                         NaN  ...
# 772                           NaN                         NaN  ...
# 773                           NaN                         NaN  ...
# 774                           NaN                         NaN  ...
#
#     Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0           NaN         NaN         NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...         ...         ...
# 770         NaN         NaN         NaN         NaN         NaN         NaN
# 771         NaN         NaN         NaN         NaN         NaN         NaN
# 772         NaN         NaN         NaN         NaN         NaN         NaN
# 773         NaN         NaN         NaN         NaN         NaN         NaN
# 774         NaN         NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24
# 0           NaN         NaN         NaN         NaN
# 1           NaN         NaN         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4           NaN         NaN         NaN         NaN
# ..          ...         ...         ...         ...
# 770         NaN         NaN         NaN         NaN
# 771         NaN         NaN         NaN         NaN
# 772         NaN         NaN         NaN         NaN
# 773         NaN         NaN         NaN         NaN
# 774         NaN         NaN         NaN         NaN
#
# [775 rows x 25 columns]
